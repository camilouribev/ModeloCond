# %% [markdown]
# # Gráficas

# %% [markdown]
# Dependencia de la transferencia de calor en condensación con el Voltaje

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


q=[113.86, 122.7, 132.1]
t_c=[2.7e-05, 3.1e-05, 3.5e-05]
V=["0 V", "100V 1 kHz", "100V 100 kHz"]


plt.bar(V, q, align='center',width=0.5, alpha=0.5)
plt.ylabel('Flux de calor condensación [W/m²]')
plt.xlabel('Voltaje [V]')

plt.show()
